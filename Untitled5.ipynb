# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/uk-optimal-product-price-prediction")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 117M/117M [00:02<00:00, 60.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/asaniczka/uk-optimal-product-price-prediction/versions/3

# %%
import kagglehub
import os

# Download latest version
dataset_path = kagglehub.dataset_download("asaniczka/uk-optimal-product-price-prediction")

# Find the CSV file within the downloaded dataset directory
for filename in os.listdir(dataset_path):
    if filename.endswith(".csv"):
        csv_file_path = os.path.join(dataset_path, filename)
        break  # Stop after finding the first CSV file

# Now use the CSV file path to read the data
import pandas as pd
df = pd.read_csv(csv_file_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
crosstab_result = pd.crosstab(df['category'], df['isBestSeller'])

# %%
crp=crosstab_result

crp["proportion"]=crp[crp.columns[1]]/(crp[crp.columns[0]]+crp[crp.columns[1]])
crp.sort_values("proportion", ascending=False)
# Out:
# isBestSeller                      False  True  proportion
# category
# Grocery                            9008   556    0.058135
# Smart Home Security & Lighting       98     6    0.057692
# Health & Personal Care             9017   552    0.057686
# Mobile Phone Accessories            248    11    0.042471
# Power & Hand Tools                 8353   306    0.035339
# ...                                 ...   ...         ...
# CD, Disc & Tape Players            8798     0    0.000000
# General Music-Making Accessories    259     0    0.000000
# Snowboard Boots                    1449     0    0.000000
# Boxes & Organisers                  911     0    0.000000
# eBook Readers & Accessories         246     0    0.000000
#
# [296 rows x 3 columns]

# %%
from scipy.stats import chi2_contingency

# Chi-square test for 'MSZoning' and 'SaleCondition'
chi2_statistic, chi2_p_value, _, _ = chi2_contingency(crosstab_result)

chi2_statistic, chi2_p_value
# Out:
# (36684.23786636857, 0.0)

# %%
crosstab_result
# Out:
# isBestSeller                    False  True  proportion
# category
# 3D Printers                       247     1    0.004032
# 3D Printing & Scanning           4065     2    0.000492
# Abrasive & Finishing Products     245     5    0.020000
# Action Cameras                   1696     1    0.000589
# Adapters                          251     3    0.011811
# ...                               ...   ...         ...
# Wind Instruments                  243     7    0.028000
# Window Treatments                 234     5    0.020921
# Women                           17559   213    0.011985
# Women's Sports & Outdoor Shoes   1939    20    0.010209
# eBook Readers & Accessories       246     0    0.000000
#
# [296 rows x 3 columns]

# %%
from scipy.stats.contingency import association
association(crosstab_result, method="cramer")
# Out:
# 0.1222829439760564

# %%
crp.sort_values(by=crp.columns[2],ascending=False).head(10).plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='category'>

# %%
df
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
def tukeys_test_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    # Define bounds for the outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify the outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]

    return outliers

# %%
tukeys_test_outliers(df["price"]).sort_values()
df_cut=df[df["price"]<100]
df_cut.value_counts("category").sort_values(ascending=False).head(20).index
df_top_20=df_cut[df_cut["category"].isin(df_cut.value_counts("category").sort_values(ascending=False).head(20).index)]
sns.violinplot(data=df_top_20, x='category', y='price', palette="coolwarm")
# Out:
# <ipython-input-74-07f3b7595453>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_top_20, x='category', y='price', palette="coolwarm")
# <Axes: xlabel='category', ylabel='price'>

# %%
df_avg_price=df.groupby(["category"])["price"].mean().sort_values(ascending=False)
df_avg_price
# Out:
# category
# Laptops                  1087.987827
# 3D Printers              1018.036129
# Desktop PCs               926.816064
# Home Office Furniture     622.135898
# Test & Measurement        559.382973
#                             ...
# Bedding Accessories         8.835220
# Adapters                    8.750197
# Signs & Plaques             8.275136
# Arts & Crafts               8.182523
# Office Paper Products       7.047684
# Name: price, Length: 296, dtype: float64

# %%
df.value_counts("category").sort_values(ascending=False).head(10).index

# %%
df_avg_price_df = df_avg_price.reset_index()

# %%
df_avg_price_df = df_avg_price_df.rename(columns={'category': 'category', 'price': 'avg_price'})

# %%
top_10_categories = df.value_counts("category").sort_values(ascending=False).head(10).index

# %%
df_avg_price_df = df_avg_price_df[df_avg_price_df['category'].isin(top_10_categories)]

# %%
sns.barplot(data=df_avg_price_df, x='category', y='avg_price', palette="coolwarm")

import matplotlib.pyplot as plt
plt.xticks(rotation=45, ha='right')
plt.tight_layout() # Adjust layout to prevent labels from being cut off

plt.show() # Display the plot
# Out:
# <ipython-input-94-a4bc73201ff2>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_avg_price_df, x='category', y='avg_price', palette="coolwarm")

# %%
sns.boxplot(data=df[df["category"].isin(top_10_categories)], x='category', y='stars', palette="coolwarm")

plt.xticks(rotation=45, ha='right')
plt.tight_layout() # Adjust layout to prevent labels from being cut off

plt.show() # Display the plot
# Out:
# <ipython-input-98-4c412ee348ea>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df[df["category"].isin(top_10_categories)], x='category', y='stars', palette="coolwarm")

# %%
median_rating=df.groupby(["category"])["stars"].mean().sort_values(ascending=False)
median_rating
# Out:
# category
# Luxury Food & Drink                       4.547570
# Grocery                                   4.469061
# Laptop Accessories                        4.449600
# Health & Personal Care                    4.439649
# Arts & Crafts                             4.432663
#                                             ...
# Motorbike Instruments                     0.166507
# 3D Printing & Scanning                    0.148267
# Motorbike Handlebars, Controls & Grips    0.125466
# Motorbike Electrical & Batteries          0.097857
# CD, Disc & Tape Players                   0.083655
# Name: stars, Length: 296, dtype: float64

# %%
#correlation between rating and price
correlation = df['price'].corr(df['stars'])
correlation
# Out:
# -0.1249067326214869

# %%
sns.scatterplot(data=df_cut, x='stars', y='price')
# Out:
# <Axes: xlabel='stars', ylabel='price'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_cut is your DataFrame

sns.jointplot(data=df_cut[df_cut['stars'] != 0], x='stars', y='price', kind='hex', color='blue', gridsize=100)

plt.show()

# %%
potential_categorical_from_numerical = df.select_dtypes("number").loc[:, df.select_dtypes("number").nunique() < 20]


df_numerical = df.select_dtypes("number").drop(columns=potential_categorical_from_numerical.columns)


correlation_matrix = df_numerical.corr()

# Setting up the matplotlib figure with an appropriate size
plt.figure(figsize=(18, 15))

# Drawing the heatmap for the numerical columns
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap for Selected Numerical Variables")
plt.show()

# %%
import statsmodels.api as sm

# Generating a Q-Q plot for 'SalePrice' to check if its distribution follows a normal distribution
sm.qqplot(df_cut['price'], line='s');

# %%
sns.histplot(df_cut['price'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='price', ylabel='Count'>
